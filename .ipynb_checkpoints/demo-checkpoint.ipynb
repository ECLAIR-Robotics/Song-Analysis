# %% [markdown]
# # Demo Model

# %%
import pandas as pd
data = pd.read_csv('./out.csv')
data.head()
# Out:
#    Unnamed: 0                                         lastfm_url  \
# 0           1  https://www.last.fm/music/metallica/_/st.%2banger
# 1           3  https://www.last.fm/music/m.i.a./_/bamboo%2bbanga
# 2           5  https://www.last.fm/music/drowning%2bpool/_/st...
# 3          11  https://www.last.fm/music/kanye%2bwest/_/feedback
# 4          13     https://www.last.fm/music/deftones/_/7%2bwords
#
#           track         artist                                       seeds  \
# 0     St. Anger      Metallica                              ['aggressive']
# 1  Bamboo Banga         M.I.A.  ['aggressive', 'fun', 'sexy', 'energetic']
# 2       Step Up  Drowning Pool                              ['aggressive']
# 3      Feedback     Kanye West                              ['aggressive']
# 4       7 Words       Deftones                     ['aggressive', 'angry']
#
#    number_of_emotion_tags  valence_tags  arousal_tags  dominance_tags  \
# ...

# %%
data['word-len'] = data['Lyric'].apply(lambda i: len(i.split(' ')))

# %%
data['word-len'].hist(bins=20)
# Out:
# <AxesSubplot: >

# %%
CUTOFF = int(data['word-len'].mean() + data['word-len'].std())

# %%
import re
data['no-punct'] = data['Lyric'].apply(lambda i: re.sub(r'[^\w\s]', '', i))
data['no-punct'] = data['no-punct'].apply(lambda i: i.lower())
data['words-split'] = data['no-punct'].apply(lambda i: re.split(' |\n', i))
data['words-split'] = data['words-split'].apply(lambda i: [j for j in i if j])

# %%
data['words-split'].head()
# Out:
# 0    [saint, anger, round, my, neck, saint, anger, ...
# 1    [road, runner, road, runner, going, hundred, m...
# 2    [come, if, our, own, lives, arent, directly, a...
# 3    [ayy, yall, heard, about, the, good, news, yal...
# 4    [ill, never, be, the, same, breaking, decency,...
# Name: words-split, dtype: object

# %%
data['trimmed'] = data['words-split'].apply(lambda i: i[:CUTOFF] if len(i) > CUTOFF else i)

# %%
import numpy as np
all_words = np.concatenate(data['trimmed'])
unique_words, counts = np.unique(all_words, return_counts=True)

# %%
sorted_words = unique_words[counts.argsort()[::-1]]

# %%
VOCAB_SIZE = 10000
most_common_words = sorted_words[:VOCAB_SIZE]

# %%
PAD = VOCAB_SIZE
UNK = VOCAB_SIZE + 1

def ordinal_encode(seq: list) -> list:
    encodings = []
    for i in seq:
        enc = np.where(most_common_words == i)[0]
        if len(enc) != 0:
            encodings.append(enc[0])
        else:
            encodings.append(UNK)
    encodings += [PAD] * (CUTOFF - len(encodings))
    return np.array(encodings)

from tqdm import tqdm as tqdm
tqdm.pandas()

data['ordinal-encoded'] = data['trimmed'].progress_apply(ordinal_encode)
# Out:
#   1%|▍                                | 247/16797 [00:03<03:28, 79.52it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [56], line 18
#      15 from tqdm import tqdm as tqdm
#      16 tqdm.pandas()
# ---> 18 data['ordinal-encoded'] = data['trimmed'].progress_apply(ordinal_encode)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.10/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
# ...

# %%
data['ordinal-encoded']
# Out:
# 0        [2281, 1552, 305, 7, 1029, 2281, 1552, 305, 7,...
# 1        [354, 4630, 354, 4630, 181, 955, 1605, 6364, 9...
# 2        [56, 39, 101, 225, 554, 1546, 10001, 8537, 114...
# 3        [2268, 539, 400, 106, 0, 108, 976, 539, 784, 1...
# 4        [66, 50, 17, 0, 202, 660, 10001, 19, 17, 816, ...
#                                ...
# 16792    [40, 1506, 41, 2855, 29, 254, 3, 4461, 263, 65...
# 16793    [12, 250, 65, 2, 25, 23, 100, 5, 745, 22, 1, 6...
# 16794    [94, 37, 1, 975, 8, 1, 123, 262, 81, 18, 2, 4,...
# 16795    [256, 1, 69, 8170, 2, 85, 47, 87, 105, 6, 151,...
# 16796    [1, 606, 74, 1091, 5, 9966, 3385, 697, 2049, 4...
# Name: ordinal-encoded, Length: 16797, dtype: object

# %%
import tensorflow as tf

inputs = tf.keras.layers.Input((CUTOFF,))
x = tf.keras.layers.Dense(CUTOFF, activation='relu')(inputs)
x = tf.keras.layers.Dense(CUTOFF, activation='relu')(x)
x = tf.keras.layers.Dropout(rate=.1)(x)
x = tf.keras.layers.Dense(CUTOFF, activation='relu')(x)
x = tf.keras.layers.Dense(3)(x)

model = tf.keras.Model(inputs=inputs, outputs=x)
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 329)]             0
#
#  dense_8 (Dense)             (None, 329)               108570
#
#  dense_9 (Dense)             (None, 329)               108570
#
#  dropout_2 (Dropout)         (None, 329)               0
#
#  dense_10 (Dense)            (None, 329)               108570
#
#  dense_11 (Dense)            (None, 3)                 990
#
# ...
# Total params: 326,700
# Trainable params: 326,700
# Non-trainable params: 0
# _________________________________________________________________

# %%
valence = data['valence_tags'].to_numpy()
arousal = data['arousal_tags'].to_numpy()
dominance = data['dominance_tags'].to_numpy()

y = np.stack([valence, arousal, dominance], axis=1)
y.shape
# Out:
# (16797, 3)

# %%
x = np.stack(data['ordinal-encoded'])
x.shape
# Out:
# (16797, 329)

# %%
model.fit(x, y, validation_split=.1, epochs=25)
# Out:
# Epoch 1/25
#   8/473 [..............................] - ETA: 3s - loss: 10547325.0000
# 2023-03-06 19:55:41.976296: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 473/473 [==============================] - ETA: 0s - loss: 218368.2812
# 2023-03-06 19:55:45.472451: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 473/473 [==============================] - 4s 8ms/step - loss: 218368.2812 - val_loss: 1122.6648
# Epoch 2/25
# 473/473 [==============================] - 3s 7ms/step - loss: 520.2433 - val_loss: 118.3181
# Epoch 3/25
# 473/473 [==============================] - 3s 7ms/step - loss: 79.0504 - val_loss: 41.4177
# Epoch 4/25
# 473/473 [==============================] - 3s 7ms/step - loss: 30.5386 - val_loss: 23.3140
# Epoch 5/25
# 473/473 [==============================] - 3s 7ms/step - loss: 17.7071 - val_loss: 18.1628
# ...

# %%
model.save('demo-model')
# Out:
# INFO:tensorflow:Assets written to: demo-model/assets

# %%
data
# Out:
#        Unnamed: 0                                         lastfm_url  \
# 0               1  https://www.last.fm/music/metallica/_/st.%2banger
# 1               3  https://www.last.fm/music/m.i.a./_/bamboo%2bbanga
# 2               5  https://www.last.fm/music/drowning%2bpool/_/st...
# 3              11  https://www.last.fm/music/kanye%2bwest/_/feedback
# 4              13     https://www.last.fm/music/deftones/_/7%2bwords
# ...           ...                                                ...
# 16792      229432       https://www.last.fm/music/noblegases/_/xenon
# 16793      229435  https://www.last.fm/music/kurt%2bvile/_/wild%2...
# 16794      229436  https://www.last.fm/music/portugal.%2bthe%2bma...
# 16795      229443  https://www.last.fm/music/porcelain%2band%2bth...
# 16796      229473  https://www.last.fm/music/daniel%2blanois/_/lo...
#
#                   track                    artist  \
# 0             St. Anger                 Metallica
# ...

# %%
to_pred = data[data['track'] == 'Transparent']['ordinal-encoded']

# %%
data[data['track'] == 'Transparent']
# Out:
#        Unnamed: 0                                         lastfm_url  \
# 16795      229443  https://www.last.fm/music/porcelain%2band%2bth...
#
#              track                    artist            seeds  \
# 16795  Transparent  Porcelain and The Tramps  ['transparent']
#
#        number_of_emotion_tags  valence_tags  arousal_tags  dominance_tags  \
# 16795                       3      6.613333      4.633333        5.773333
#
#       mbid spotify_id       genre  \
# 16795  NaN        NaN  industrial
#
#                                                    Lyric language  word-len  \
# 16795  Wish I were transparent\nYou could see right t...       en        30
#
#                                                 no-punct  \
# 16795  wish i were transparent\nyou could see right t...
#
#                                              words-split  \
# 16795  [wish, i, were, transparent, you, could, see, ...
#
#                                                  trimmed  \
# ...

# %%
model.predict(np.stack(to_pred))
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[5.4766026, 4.422446 , 5.315414 ]], dtype=float32)
